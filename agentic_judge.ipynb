# %% [markdown]
# #LLM Translation Judge for English-to-Filipino Translations via Prompt Engineering

# %% [markdown]
# ## Installation of Dependencies

# %%
from google.colab import ai
import pandas as pd
import urllib.request
import numpy as np
from scipy.stats import spearmanr
import time
import random
import re

# %% [markdown]
# ## Importing, Pre-processing, and Cleaning the dataset

# %% [markdown]
# ### Importing the dataset
#
# The dataset was downloaded from google sheets and uploaded into a public repository in github. From there the dataset is loaded into the notebook using urllib

# %%
url = 'https://raw.githubusercontent.com/CarandangR/CSC420M-LLM-Translation-Judge-for-English-to-Filipino-Translations/main/Datasets%20-%20Training.csv'
filename = 'training_dataset.csv'

urllib.request.urlretrieve(url, filename)
# Out:
# ('training_dataset.csv', <http.client.HTTPMessage at 0x7bc2e7359950>)

# %%
df = pd.read_csv(filename)

df.head()
# Out:
#                                              English  \
# 0                                Ang gnda na mura pa
# 1  The Philippines is an archipelago made up of o...
# 2  Philippines is the world's second-largest arch...
# 3  Filipino and English are the two official lang...
# 4  Tagalog is the most widely spoken native langu...
#
#                                     Filipino-Correct  \
# 0          It so beautiful and it's even affordable.
# 1  Ang Pilipinas ay isang kapulaang binubuo ng 7,...
# 2  Ang Pilipinas ang pangalawa sa pinakamalaking ...
# 3  Filipino at Ingles ang dalawang opisyal na lin...
# 4  Tagalog ang pinakamalawak at ginagamit na katu...
#
#                                      Filipino-Flawed  \
# 0                                beautiful and cheap
# 1  Ang Pilipinas ay isang puno na binubuo ng mahi...
# 2  Ang Pilipinas ay ang pangalawang malaking isla...
# 3  Tagalog at Ingles ang dalawa opisyal lingwahe ...
# 4  Tagalog ay ang pinaka malawak sinasabi katutub...
#
#                                              Remarks  \
# 0  flawed translation failed to express the 'na' ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             Contributor
# 0                       Charibeth Cheng
# 1  Geena Tibule/Charlyne Arajoy Carabeo
# 2  Geena Tibule/Charlyne Arajoy Carabeo
# 3  Geena Tibule/Charlyne Arajoy Carabeo
# 4  Geena Tibule/Charlyne Arajoy Carabeo

# %% [markdown]
# ### Displaying the info of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564 entries, 0 to 563
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   English           562 non-null    object
#  1   Filipino-Correct  562 non-null    object
#  2   Filipino-Flawed   562 non-null    object
#  3   Remarks           333 non-null    object
#  4   Contributor       562 non-null    object
# dtypes: object(5)
# memory usage: 22.2+ KB

# %% [markdown]
# ## Dataset Cleaning

# %% [markdown]
# ### Dropping Rows with missing `English` or `Filipino-Correct/Filipino/Flawed` Texts

# %%
df_cleaned = df.dropna(subset=['English', 'Filipino-Correct', 'Filipino-Flawed']).copy()

# %% [markdown]
# ### Renaming of columns
#
# This is for the columns to be easily handled by the LLM. This is how each column was renamed:
# *   `English` was turned into `source_text`
# *   `Filipino-Correct` was turned into `reference_translation`
# *   `Filipino-Flawed` was turned into `translated_text`

# %%
df_cleaned.rename(columns={
    'English': 'source_text',
    'Filipino-Correct': 'reference_translation',
    'Filipino-Flawed': 'translated_text',
}, inplace=True)

# %% [markdown]
# ### Checking of duplicate strings

# %%
df_cleaned = df_cleaned[
    (df_cleaned['source_text'].str.strip() != '') &
    (df_cleaned['translated_text'].str.strip() != '')
].drop_duplicates(subset=['source_text', 'translated_text'])

# %% [markdown]
# ### Displaying Cleaned dataset

# %%
df_cleaned.sample(5)
# Out:
#                                            source_text  \
# 294                                Please take a seat.
# 113  Then you will pay for your transgressions, Ale...
# 271                    I am playing games on my phone.
# 187  In object-oriented programming, inheritance pr...
# 436  I know you're leaving in the morning when you ...
#
#                                  reference_translation  \
# 294                                     Maupo po kayo.
# 113  Kung gayon, pagbabayaran mo ang iyong mga pagl...
# 271             Naglalaro ako ng games sa akin selpon.
# 187  Sa object-oriented programming, pinapalaganap ...
# 436          Alam kong aalis ka sa umaga pag-ising mo.
#
#                                        translated_text  \
# 294                              Kumuha kayo ng upuan.
# 113  Edi babayaran mo ang iyong mga mali, Alexandra...
# 271       Naglalaro ako ng ng games sa aking selphone.
# 187                Inheritance ay nagpaparami ng code.
# 436          Alam ko aalis ka sa umaga pagkagising mo.
#
#                                                Remarks  \
# 294                                Literal translation
# 113  flawed translation does not match formality of...
# 271                incorrect translation of cellphone.
# 187                                                NaN
# 436                                                NaN
#
#                               Contributor
# 294      Sherwynn Angeles / Gregory Tiong
# 113  Elijah Rosario/John Kirsten Espiritu
# 271      Sherwynn Angeles / Gregory Tiong
# 187                Camron Ong / Arvin Tan
# 436        Ryan Carandang/ Riley Veracruz

# %% [markdown]
# ## Declaring the Prompting template

# %% [markdown]
# This template was made to take into consideration the different requirements specified in the machine project specifications. Things like Accuracy, Fluency, Coherence, Cultural Appropriateness, and Completeness are criterias that the LLM will evaluate on.

# %%
prompt = """
You are a strict translation judge evaluating an English-to-Filipino translation. Your task is to Evaluate and score the translated text.

### Task Overview:
Generate an evaluation from the english source text, the translated text, and the reference translation.
English source text: {source_text}
Translated text: {translated_text}
Reference text: {reference_translation}
Note that the reference translation is the correct translation of the source text so it will get the perfect score. Keep in mind when evaluating

### Evaluation Criteria:
Each criteria below will be either 0 or 1 point each. The perfect score of the translation is 6 points and the lowest score is 0 points.
The criteria can only have a score of 1 if they meed the requirements of the criteria. otherwise it will always be 0.
1. Accuracy – Deduct if any part of the meaning differs from the reference or omits details.
2. Fluency – Deduct if grammar, style, or idiomatic expression is less natural than the reference.
3. Coherence – Deduct if the logical flow or structure differs from the reference without valid reason.
4. Cultural Appropriateness – Deduct if cultural tone, idioms, or respectful forms differ in a way that harms the message.
5. Guideline Adherence – Deduct if terminology/style differs from the reference in a way that breaks domain rules.
6. Completeness – Deduct if any information present in the reference is missing or altered.

### Sample Output
{source_text}
{translated_text}
Accuracy: 1 point (The translated text accurately conveys the meaning of the source text, with no omitted details or changed meaning.)
Fluency: 0 point (The sentence structure is not as natural as the reference, and the use of "may" and "sawsawan" makes the text less fluent.)
Coherence: 0 point (The logical flow of the sentence is not as clear as the reference, and the use of "may" and "sawsawan" disrupts the coherence.)
Cultural Appropriateness: 1 point (The use of "bagoon alamang" and "kare-kare" is culturally appropriate and respectful.)
Guideline Adherence: 0 point (The use of "may" and "sawsawan" deviates from the guideline of using more natural and idiomatic expressions.)
Completeness: 1 point (The translated text includes all the information present in the reference.)
Total Score: 3 points
"""

# %% [markdown]
# ## Import and setup of the Large Language Model

# %% [markdown]
# ### Import of the Large Language Model through the use of the API key

# %%
ai.list_models()
# Out:
# ['google/gemini-2.0-flash',
#  'google/gemini-2.0-flash-lite',
#  'google/gemini-2.5-flash',
#  'google/gemini-2.5-flash-lite',
#  'google/gemini-2.5-pro',
#  'google/gemma-3-12b',
#  'google/gemma-3-1b',
#  'google/gemma-3-27b',
#  'google/gemma-3-4b']

# %% [markdown]
# ### Selecting Random Prompts to test different types of Promts

# %%
random_idx = random.choice(df_cleaned.index)
random_row = df_cleaned.loc[random_idx]

# %%
source_text = random_row['source_text']
translated_text = random_row['translated_text']
reference_translation = random_row.get('reference_translation')

# %%
formatted_prompt = prompt.format(
    source_text=source_text,
    translated_text=translated_text,
    reference_translation=reference_translation
)

# %% [markdown]
# ###

# %%
response = ai.generate_text(formatted_prompt, model_name='google/gemini-2.5-pro')

# %%
print("Raw Response for Example 1:")
print(response)
# Out:
# Raw Response for Example 1:
# The risk of developing certain cancers can be reduced by not smoking, maintaining a healthy weight, limiting alcohol intake, and eating plenty of vegetables.
# Ang panganib na magkaroon ng ilang mga kanser ay maaaring mabawasan sa pamamagitan ng hindi paninigarilyo, pagpapanatili ng malusog na timbang, paglilimita sa pag-inom ng alak, at pagkain ng maraming gulay.
# **Accuracy:** 0 point (The translated text uses "hindi paninigarilyo" (a state of not smoking), which differs in meaning from the reference's "pagiwas sa paninigarilyo" (the action of avoiding smoking). The reference more accurately captures the preventative action implied in the source.)
# **Fluency:** 0 point (The phrase "hindi paninigarilyo" is a literal translation that is less natural and idiomatic than the reference's "pagiwas sa paninigarilyo," which is the standard and more fluent phrasing in this context.)
# **Coherence:** 1 point (The overall sentence structure and logical flow are identical to the reference text. The list of actions is clear and follows the same coherent pattern.)
# **Cultural Appropriateness:** 1 point (The tone and language are neutral and appropriate for a public health announcement, with no culturally sensitive issues.)
# **Guideline Adherence:** 0 point (The reference translation sets the guideline for correct terminology. The translated text deviates by using "hindi paninigarilyo" instead of the standard and more appropriate term "pagiwas sa paninigarilyo.")
# **Completeness:** 0 point (The translated text alters the information present in the reference. The reference's concept of "pagiwas sa" (avoiding) is altered to a simple negation "hindi" (not), which changes the nuance of the action described.)
# **Total Score:** 2 points

# %% [markdown]
# ## Testing using Validation set

# %% [markdown]
# ### Loading Validation set

# %%
valurl = 'https://raw.githubusercontent.com/CarandangR/CSC420M-LLM-Translation-Judge-for-English-to-Filipino-Translations/main/Datasets%20-%20Human-Labeled%20Validation%20Set.csv'

valfilename = 'validation_dataset.csv'
urllib.request.urlretrieve(valurl, valfilename)
# Out:
# ('validation_dataset.csv', <http.client.HTTPMessage at 0x7bc2e695a350>)

# %%
val_df = pd.read_csv(valfilename)

val_df.head()
# Out:
#                                Source Text (English)  \
# 0  The children laughed and played under the afte...
# 1           She took a break to gather her thoughts.
# 2  The algorithm efficiently identifies patterns ...
# 3  Data normalization helps improve model perform...
# 4  alam mo ma'am masaya naman topics natin sa phi...
#
#                               Target Text (Filipino)  Final_score  \
# 0  Ang mga bata ay nagtawanan at naglaro sa ilali...          4.0
# 1                Nagpahinga siya para mag-isip-isip.          4.0
# 2  Mabisang kinikilala ng algoritmo ang mga patte...          3.0
# 3  Tumutulong sa pagpabuti ng model ang normalisa...          5.0
# 4  You know, ma'am, we have a lot of fun philosop...          4.0
#
#                                  Rater 1 Explanation  \
# 0  Accurate, fluent, and natural translation. Cap...
# 1  The translation is accurate. It was able to ca...
# 2  The translation of "identifies" as "kinikilala...
# 3  The translated text is natural and captures th...
# 4  flawed translation is close, but failed to tra...
#
#                                  Rater 2 Explanation  \
# 0  Just slight error due to the literal translati...
# 1  The translation would have been better if the ...
# 2  The translation would have been better if the ...
# 3  The translation didn't literally translated th...
# 4                                                NaN
#
#                          Contributor
# 0  Paul Ivan Enclonar/Alonzo Rimando
# 1  Paul Ivan Enclonar/Alonzo Rimando
# 2  Paul Ivan Enclonar/Alonzo Rimando
# 3  Paul Ivan Enclonar/Alonzo Rimando
# 4                    Charibeth Cheng

# %% [markdown]
# ### Validation Set Cleaning

# %% [markdown]
# Dropping rows with missign `Source Text (English)`, `Target Text (Filipino)`, and `Final Score (1 - lowest, 5 - highest)` columns

# %%
val_df_cleaned = val_df.dropna(subset=['Source Text (English)', 'Target Text (Filipino)', 'Final_score']).copy()

# %% [markdown]
# Renaming of Columns
#
# This is for the columns to be easily handled by the LLM. This is how each column was renamed:
# *   `Source Text (English)` was turned into `source_text`
# *   `Target Text (Filipino)` was turned into `target_text`
# *   `Final Score (1 - lowest, 5 - highest)` was turned into `score`

# %%
val_df_cleaned.rename(columns={
    'Source Text (English)': 'source_text',
    'Target Text (Filipino)': 'target_text',
    'Final_score': 'score',
}, inplace=True)

# %% [markdown]
# Checking of duplicate strings

# %%
val_df_cleaned = val_df_cleaned[
    (val_df_cleaned['source_text'].str.strip() != '') &
    (val_df_cleaned['target_text'].str.strip() != '')
].drop_duplicates(subset=['source_text', 'target_text'])

# %% [markdown]
# Checking Cleaned dataset

# %%
val_df_cleaned.sample(5)
# Out:
#                                           source_text  \
# 56  Taking crazy things seriously is a serious was...
# 11  Mark accidentally let the cat out of the bag a...
# 37  Jollibee is a famous fast food restaurant in t...
# 41  The hospitability of Filipinos are known world...
# 15  This guy right here is Shadow, and he's kinda ...
#
#                                           target_text  score  \
# 56  Ang pagseseryoso ng mga bagay na baliw ay isan...    5.0
# 11  Hindi sinasadyang nailabas ni Mark ang pusa mu...    3.0
# 37  Ang Jollibee ay isang sikat na kainan sa Pilip...    4.0
# 41  Ang pagiging hospitable ng mga Pilipino ay kil...    4.0
# 15  Ang lalaking ito dito ay si Shadow, at siya an...    1.0
#
#                                   Rater 1 Explanation  \
# 56  Captures tone and meaning well, using native-s...
# 11  Complete, and gramatically correct. However, t...
# 37  Better to phrase it as “Ang Jollibee ay isa sa...
# 41  kilala could be replaced with alam which would...
# 15     "Ang lalaking ito dito" should not have "dito"
#
#                                   Rater 2 Explanation  \
# 56  It uses words that flow naturally and matches ...
# 11                 Idiom was not translated correctly
# 37           - accurate translation\r\n- good grammar
# 41                 kilala could be replace with sikat
# 15  buzz-kill is not translated. also "totoong buz...
#
#                              Contributor
# 56   Lia Guillermo/Lester Anthony Sityar
# 11     Boris Victoria / Joel Ethan Batac
# 37                     Joaquin de Guzman
# 41  Charlyne Arajoy Carabeo/Geena Tibule
# 15  Elijah Rosario/John Kirsten Espiritu

# %%
val_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57 entries, 0 to 63
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   source_text          57 non-null     object
#  1   target_text          57 non-null     object
#  2   score                57 non-null     float64
#  3   Rater 1 Explanation  57 non-null     object
#  4   Rater 2 Explanation  54 non-null     object
#  5   Contributor          57 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 3.1+ KB

# %% [markdown]
# Define prompt to use for validation

# %%
prompt = """
You are a strict translation judge evaluating an English-to-Filipino translation. Your task is to Evaluate and score the translated text.

### Task Overview:
Generate an evaluation from the english source text, the translated text, and the reference translation.
English source text: {source_text}
Translated text: {translated_text}

### Evaluation Criteria:
Each criteria below will be either 0 or 1 point each. The perfect score of the translation is 6 points and the lowest score is 0 points.
The criteria can only have a score of 1 if they meed the requirements of the criteria. otherwise it will always be 0.
1. Accuracy – Deduct if any part of the meaning differs from the reference or omits details.
2. Fluency – Deduct if grammar, style, or idiomatic expression is less natural than the reference.
3. Coherence – Deduct if the logical flow or structure differs from the reference without valid reason.
4. Cultural Appropriateness – Deduct if cultural tone, idioms, or respectful forms differ in a way that harms the message.
5. Guideline Adherence – Deduct if terminology/style differs from the reference in a way that breaks domain rules.
6. Completeness – Deduct if any information present in the reference is missing or altered.

### Sample Output
The algorithm efficiently identifies patterns in large datasets.
Mabisang kinikilala ng algoritmo ang mga pattern sa malalaking dataset.
Accuracy: 1 point (The translated text accurately conveys the meaning of the source text, with no omitted details or changed meaning.)
Fluency: 0 point (The sentence structure is not as natural as the reference, and the use of "may" and "sawsawan" makes the text less fluent.)
Coherence: 0 point (The logical flow of the sentence is not as clear as the reference, and the use of "may" and "sawsawan" disrupts the coherence.)
Cultural Appropriateness: 1 point (The use of "bagoon alamang" and "kare-kare" is culturally appropriate and respectful.)
Guideline Adherence: 0 point (The use of "may" and "sawsawan" deviates from the guideline of using more natural and idiomatic expressions.)
Completeness: 1 point (The translated text includes all the information present in the reference.)
Total Score: 3 points
"""

# %% [markdown]
# #Agentic System

# %% [markdown]
# ## Defining LLM Wrapper (serves as the "Brain")

# %%
import requests

def check_fluency_languagetool(text):
    url = "https://api.languagetool.org/v2/check"
    data = {
        'text': text,
        'language': 'tl',  # Tagalog, or use 'en' for English etc.
    }
    response = requests.post(url, data=data).json()
    # Return the number of errors found or confidence score
    return len(response.get('matches', []))

# %%
# LLM wrapper for Google Gemini in Colab
class LLMWrapper:
    def __init__(self, model_name='google/gemini-2.5-pro'):
        self.model_name = model_name

    def generate(self, prompt):
        # Calls the built-in ai.generate_text method available in your Colab
        response = ai.generate_text(prompt, model_name=self.model_name)
        return response

# %% [markdown]
# ##Memory Module

# %%
# Memory to store step-by-step evaluations and final results
class MemoryModule:
    def __init__(self):
        self.memory = {}

    def store(self, step_name, content):
        self.memory[step_name] = content

    def retrieve(self, step_name):
        return self.memory.get(step_name, "")

    def get_all(self):
        return self.memory

# %% [markdown]
# ## Planning and Reasoning Engine (Prompt Builder and response parser) + LanguageTool for Fluency

# %%
# Handles structured evaluation prompts for each criterion
import requests

def check_fluency_languagetool(text):
    url = "https://api.languagetool.org/v2/check"
    data = {
        'text': text,
        'language': 'tl',  # Change to 'en' for English, etc.
    }
    try:
        response = requests.post(url, data=data)
        response.raise_for_status()  # Raises error for bad status
        result = response.json()
        error_count = len(result.get('matches', []))
        print(f"LanguageTool found {error_count} errors.")  # Debug print
        return error_count
    except Exception as e:
        print(f"LanguageTool API error: {e}")
        return -1  # Indicate failure

class EvaluationSteps:
    def __init__(self, llm, memory):
        self.llm = llm
        self.memory = memory

    def execute_step(self, step_name, prompt):
        print(f"\n--- Agent Thought: Executing {step_name} ---")
        response = self.llm.generate(prompt)
        print(f"--- Agent Observation ({step_name}): ---\n{response}\n")
        self.memory.store(step_name, response)
        return response

    def accuracy(self, source, translated, reference):
        return self.execute_step("accuracy", f"""
Source: "{source}"
Translated: "{translated}"
Reference: "{reference}"

Task: Evaluate ACCURACY.
Deduct a point if meaning differs or omits details.
Score 1 if accurate, 0 otherwise.

Format:
Score: <0 or 1>
Explanation: <your analysis>
""")

    def fluency(self, source, translated, reference):
        error_count = check_fluency_languagetool(translated)
        print(f"LanguageTool detected {error_count} errors in the translation.")
        prompt = f"""
Source: "{source}"
Translated: "{translated}"
Reference: "{reference}"

Additional Info:
LanguageTool detected {error_count} potential grammar/style/spelling errors in the translated text.

Task: Evaluate FLUENCY.
Deduct a point if grammar/style/idiomatic use is unnatural.
Score 1 if fluent, 0 otherwise.

Format:
Score: <0 or 1>
Explanation: <your analysis>
"""
        return self.execute_step("fluency", prompt)

    def coherence(self, source, translated, reference):
        return self.execute_step("coherence", f"""
Source: "{source}"
Translated: "{translated}"
Reference: "{reference}"

Task: Evaluate COHERENCE.
Deduct a point if logical flow differs without reason.
Score 1 if coherent, 0 otherwise.

Format:
Score: <0 or 1>
Explanation: <your analysis>
""")

    def cultural_appropriateness(self, source, translated, reference):
        return self.execute_step("cultural_appropriateness", f"""
Source: "{source}"
Translated: "{translated}"
Reference: "{reference}"

Task: Evaluate CULTURAL APPROPRIATENESS.
Deduct a point if tone/idioms/forms differ in a way that harms meaning.
Score 1 if appropriate, 0 otherwise.

Format:
Score: <0 or 1>
Explanation: <your analysis>
""")

    def guideline_adherence(self, source, translated, reference):
        return self.execute_step("guideline_adherence", f"""
Source: "{source}"
Translated: "{translated}"
Reference: "{reference}"

Task: Evaluate GUIDELINE ADHERENCE.
Deduct a point if terminology/style violates domain rules.
Score 1 if adheres, 0 otherwise.

Format:
Score: <0 or 1>
Explanation: <your analysis>
""")

    def completeness(self, source, translated, reference):
        return self.execute_step("completeness", f"""
Source: "{source}"
Translated: "{translated}"
Reference: "{reference}"

Task: Evaluate COMPLETENESS.
Deduct a point if information in reference is missing or altered.
Score 1 if complete, 0 otherwise.

Format:
Score: <0 or 1>
Explanation: <your analysis>
""")

# %% [markdown]
# ## Synthesis Tool

# %%
class FinalSynthesisTool:
    def __init__(self, llm, memory):
        self.llm = llm
        self.memory = memory

    def synthesize(self):
        prompt = f"""
You have performed the following analyses:

- Accuracy: {self.memory.retrieve('accuracy')}
- Fluency: {self.memory.retrieve('fluency')}
- Coherence: {self.memory.retrieve('coherence')}
- Cultural Appropriateness: {self.memory.retrieve('cultural_appropriateness')}
- Guideline Adherence: {self.memory.retrieve('guideline_adherence')}
- Completeness: {self.memory.retrieve('completeness')}

Return a JSON object:
{{
  "scores": {{
    "accuracy": <0 or 1>,
    "fluency": <0 or 1>,
    "coherence": <0 or 1>,
    "cultural_appropriateness": <0 or 1>,
    "guideline_adherence": <0 or 1>,
    "completeness": <0 or 1>,
    "total": <sum>
  }},
  "explanation": "<comprehensive synthesis>"
}}
"""
        print("\n--- Agent Thought: Synthesizing Final Judgment ---")
        result_str = self.llm.generate(prompt)

        import json
        try:
            start = result_str.find("{")
            end = result_str.rfind("}") + 1
            result_json = json.loads(result_str[start:end])

            # Normalize total score and add label
            total = result_json["scores"].get("total", 0)
            if total >= 5:
                norm_score = 5
                label = "excellent"
            elif 3 <= total <= 4:
                norm_score = 3
                label = "good"
            else:
                norm_score = 1
                label = "poor"

            result_json["scores"]["normalized_total"] = norm_score
            result_json["scores"]["label"] = label

            return result_json

        except Exception as e:
            print(f"Error parsing JSON: {e}")
            return {"error": "Invalid JSON"}

# %% [markdown]
# ## Orchestration Layer

# %%
# Controls the sequence: Thought → Action → Observation
class AgenticJudge:
    def __init__(self, llm):
        self.memory = MemoryModule()
        self.steps = EvaluationSteps(llm, self.memory)
        self.final_synthesizer = FinalSynthesisTool(llm, self.memory)

    def evaluate(self, source, translated, reference):
        print(f"Evaluating: \"{source}\" → \"{translated}\"\n")
        print("--- Model initialized successfully. ---\n")
        print("--- STARTING AGENTIC EVALUATION ---\n")

        self.steps.accuracy(source, translated, reference)
        self.steps.fluency(source, translated, reference)
        self.steps.coherence(source, translated, reference)
        self.steps.cultural_appropriateness(source, translated, reference)
        self.steps.guideline_adherence(source, translated, reference)
        self.steps.completeness(source, translated, reference)

        final_result = self.final_synthesizer.synthesize()
        print("\n--- FINAL EVALUATION ---")
        print(json.dumps(final_result, indent=2, ensure_ascii=False))
        return final_result

# %% [markdown]
# Accepting a translation pair

# %%
import json
import pandas as pd

# %%
# 1. Create the LLM "brain"
llm = LLMWrapper(model_name="google/gemini-2.5-pro")

# 2. Create the agent
judge = AgenticJudge(llm=llm)

# 3. Define your test inputs
source_text = "I love eating fresh mangoes in the summer."
translated_text = "Mahilig akong kumain ng bagong mangga tuwing bakasyon."
reference_text = "Mahilig akong kumain ng sariwang mangga tuwing tag-init."

# 4. Run the evaluation
result = judge.evaluate(source_text, translated_text, reference_text)
# Out:
# Evaluating: "I love eating fresh mangoes in the summer." → "Mahilig akong kumain ng bagong mangga tuwing bakasyon."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 0
# Explanation: The translation is inaccurate. "Fresh" was translated as "bago" (new) instead of "sariwa". Additionally, "summer" was translated as "bakasyon" (vacation) instead of the correct term "tag-init". These are significant changes in meaning.
#
# LanguageTool found 0 errors.
# LanguageTool detected 0 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 0
# Explanation: The translation is grammatically correct, but it is not fluent due to unnatural word choices. The word "bagong" translates to "new," which is not the correct term for "fresh" in the context of fruit; the proper word is "sariwa." Additionally, "bakasyon" means "vacation," not "summer." The correct term for the summer season is "tag-init." These choices make the sentence sound unnatural and non-idiomatic.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translated sentence is grammatically correct and presents a complete, logical thought. While "bagong mangga" (new mangoes) and "bakasyon" (vacation) are not the most accurate translations for "fresh mangoes" and "summer," the resulting sentence is still perfectly coherent and understandable on its own. It does not contain any breaks in logic. The issues here relate to accuracy, not coherence.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 0
# Explanation: The translation uses "bakasyon" (vacation) for "summer." In the Philippines, while the main school vacation often falls during summer, the correct term for the season is "tag-init." The source connects the love for mangoes to the season in which they are fresh and abundant. Using "bakasyon" changes the context from a seasonal appreciation to a vacation activity, which harms the original meaning and loses a key cultural nuance. The reference's use of "tag-init" is the culturally and literally correct term.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 0
# Explanation: The translation violates terminology rules. It incorrectly translates "fresh" as "bago" (new) instead of the correct term "sariwa". It also incorrectly translates "summer" as "bakasyon" (vacation) instead of the correct term for the season, "tag-init".
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 0
# Explanation: The translation alters two key pieces of information. "Fresh" is translated as "bagong" (new) instead of the correct "sariwang." "Summer" is translated as "bakasyon" (vacation) instead of "tag-init" (summer), which is the correct term for the season.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 0,
#     "fluency": 0,
#     "coherence": 1,
#     "cultural_appropriateness": 0,
#     "guideline_adherence": 0,
#     "completeness": 0,
#     "total": 1,
#     "normalized_total": 1,
#     "label": "poor"
#   },
#   "explanation": "The translation is inaccurate and unnatural due to two significant terminological errors. Firstly, \"fresh\" was incorrectly translated as \"bago\" (new) instead of the proper term \"sariwa.\" Secondly, \"summer\" was translated as \"bakasyon\" (vacation) instead of the correct term for the season, \"tag-init.\" These errors substantially alter the original meaning, making the translation incomplete and non-adherent to terminology guidelines. The use of \"bakasyon\" for \"summer\" also loses an important cultural nuance, changing the context from a seasonal appreciation to a vacation activity. While the resulting sentence is grammatically correct and coherent on its own, the incorrect word choices make it sound unnatural and non-idiomatic."
# }

# %% [markdown]
# ## Batch Processing of Data

# %% [markdown]
# ### finding last completed index

# %%
# Load original full validation dataframe
val_df_with_scores = val_df_cleaned.copy()

# Load partial results with normalized_total (may be shorter)
partial_df = pd.read_csv('validation_with_normalized_scores_partial.csv')

# Make sure partial_df has 'normalized_total' column
if 'normalized_total' in partial_df.columns:
    # Merge partial results by index into full df
    val_df_with_scores['normalized_total'] = None  # Initialize

    # Assign normalized_total from partial_df to full df for matching indices
    for idx, val in partial_df['normalized_total'].items():
        val_df_with_scores.at[idx, 'normalized_total'] = val
else:
    val_df_with_scores['normalized_total'] = None

# Find last completed index on full df
completed_rows = val_df_with_scores['normalized_total'].notnull()
last_completed_index = completed_rows[completed_rows].index.max() if completed_rows.any() else -1

print(f"Last completed index on full df: {last_completed_index}")

# Then continue with batch processing from last_completed_index+1 on full df
# (use the batch processing code from previous message here)
# Out:
# Last completed index on full df: 9

# %%
import json
import pandas as pd

batch_size = 10
val_df_with_scores = val_df_cleaned.copy()

# Initialize the full-length list with None
normalized_scores = [None] * len(val_df_with_scores)

for start_idx in range(0, len(val_df_with_scores), batch_size):
    end_idx = min(start_idx + batch_size, len(val_df_with_scores))
    print(f"Processing rows {start_idx} to {end_idx - 1}...")

    for idx in range(start_idx, end_idx):
        row = val_df_with_scores.iloc[idx]
        source = row['source_text']
        translated = row['target_text']

        try:
            final_eval = judge.evaluate(source, translated, reference=translated)
        except Exception as e:
            print(f"Error evaluating row {idx}: {e}")
            final_eval = {"scores": {"normalized_total": None}}

        norm_score = final_eval.get("scores", {}).get("normalized_total", None)
        normalized_scores[idx] = norm_score  # Update specific position

        print("\n--- FINAL EVALUATION ---")
        print(json.dumps(final_eval, indent=2, ensure_ascii=False))

    # Assign only the processed batch slice
    val_df_with_scores.iloc[start_idx:end_idx - 1, 'normalized_total'] = normalized_scores[start_idx:end_idx]

    # Save intermediate results after each batch
    val_df_with_scores.iloc[:end_idx].to_csv('validation_with_normalized_scores_partial.csv', index=False, encoding='utf-8-sig')

    print(f"Saved partial results up to row {end_idx - 1}")

print("Batch processing complete!")

# Save final results
val_df_with_scores['normalized_total'] = normalized_scores
val_df_with_scores.to_csv('validation_with_normalized_scores_final.csv', index=False, encoding='utf-8-sig')
print("Saved final results as validation_with_normalized_scores_final.csv")
# Out:
# Processing rows 0 to 9...
# Evaluating: "The children laughed and played under the afternoon sun." → "Ang mga bata ay nagtawanan at naglaro sa ilalim ng hapon na araw."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 1
# Explanation: The translation is a perfect and literal match for the source sentence. All components are accurately translated: "The children" as "Ang mga bata," "laughed and played" as "nagtawanan at naglaro," and "under the afternoon sun" as "sa ilalim ng hapon na araw." The meaning is fully preserved without any omissions or alterations.
#
# LanguageTool found 2 errors.
# LanguageTool detected 2 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1504408526.py in <cell line: 0>()
#      18
#      19         try:
# ---> 20             final_eval = judge.evaluate(source, translated, reference=translated)
#      21         except Exception as e:
#      22             print(f"Error evaluating row {idx}: {e}")
#
# /tmp/ipython-input-1740023961.py in evaluate(self, source, translated, reference)
#      12
#      13         self.steps.accuracy(source, translated, reference)
# ---> 14         self.steps.fluency(source, translated, reference)
#      15         self.steps.coherence(source, translated, reference)
#      16         self.steps.cultural_appropriateness(source, translated, reference)
#
# /tmp/ipython-input-499665800.py in fluency(self, source, translated, reference)
#      65 Explanation: <your analysis>
#      66 """
# ---> 67         return self.execute_step("fluency", prompt)
#      68
#      69     def coherence(self, source, translated, reference):
#
# /tmp/ipython-input-499665800.py in execute_step(self, step_name, prompt)
#      26     def execute_step(self, step_name, prompt):
#      27         print(f"\n--- Agent Thought: Executing {step_name} ---")
# ---> 28         response = self.llm.generate(prompt)
#      29         print(f"--- Agent Observation ({step_name}): ---\n{response}\n")
#      30         self.memory.store(step_name, response)
#
# /tmp/ipython-input-25894194.py in generate(self, prompt)
#       6     def generate(self, prompt):
#       7         # Calls the built-in ai.generate_text method available in your Colab
# ----> 8         response = ai.generate_text(prompt, model_name=self.model_name)
#       9         return response
#
# /usr/local/lib/python3.11/dist-packages/google/colab/ai.py in generate_text(prompt, model_name, stream)
#      83   )
#      84
# ---> 85   response = client.chat.completions.create(
#      86       model=model_name,
#      87       messages=[{'role': 'user', 'content': prompt}],
#
# /usr/local/lib/python3.11/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     285                         msg = f"Missing required argument: {quote(missing[0])}"
#     286                 raise TypeError(msg)
# --> 287             return func(*args, **kwargs)
#     288
#     289         return wrapper  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1133     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1134         validate_response_format(response_format)
# -> 1135         return self._post(
#    1136             "/chat/completions",
#    1137             body=maybe_transform(
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1257             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258         )
# -> 1259         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1260
#    1261     def patch(
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#     980             response = None
#     981             try:
# --> 982                 response = self._client.send(
#     983                     request,
#     984                     stream=stream or self._should_stream_response_body(request=request),
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     248         )
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#     252         assert isinstance(resp.stream, typing.Iterable)
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     254
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#     258         # Return the response. Note that in this case we still have to manage
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     234                 try:
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#     238                     )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     101             raise exc
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#     105     def _connect(self, request: Request) -> NetworkStream:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     134                 with Trace("response_closed", logger, request) as trace:
#     135                     self._response_closed()
# --> 136             raise exc
#     137
#     138     # Sending the request...
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     104                     headers,
#     105                     trailing_data,
# --> 106                 ) = self._receive_response_headers(**kwargs)
#     107                 trace.return_value = (
#     108                     http_version,
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     175
#     176         while True:
# --> 177             event = self._receive_event(timeout=timeout)
#     178             if isinstance(event, h11.Response):
#     179                 break
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# /usr/lib/python3.11/ssl.py in recv(self, buflen, flags)
#    1293                     "non-zero flags not allowed in calls to recv() on %s" %
#    1294                     self.__class__)
# -> 1295             return self.read(buflen)
#    1296         else:
#    1297             return super().recv(buflen, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1166                 return self._sslobj.read(len, buffer)
#    1167             else:
# -> 1168                 return self._sslobj.read(len)
#    1169         except SSLError as x:
#    1170             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Process by batches of 10

# %%
import json
import pandas as pd

batch_size = 10
val_df_with_scores = val_df_cleaned.copy()

# Load partial results CSV if exists
try:
    partial_df = pd.read_csv('validation_with_normalized_scores_partial.csv')
    if 'normalized_total' in partial_df.columns:
        val_df_with_scores['normalized_total'] = None
        for idx, val in partial_df['normalized_total'].items():
            val_df_with_scores.at[idx, 'normalized_total'] = val
except FileNotFoundError:
    val_df_with_scores['normalized_total'] = None

# Find last completed index
completed_rows = val_df_with_scores['normalized_total'].notnull()
last_completed_index = completed_rows[completed_rows].index.max() if completed_rows.any() else -1

print(f"Last completed index on full df: {last_completed_index}")

start_idx = last_completed_index + 1
total_rows = len(val_df_with_scores)

normalized_scores = val_df_with_scores['normalized_total'].tolist()  # get existing scores list (with Nones)

for batch_start in range(start_idx, total_rows, batch_size):
    batch_end = min(batch_start + batch_size, total_rows)
    print(f"Processing rows {batch_start} to {batch_end - 1}...")

    for idx in range(batch_start, batch_end):
        row = val_df_with_scores.iloc[idx]
        source = row['source_text']
        translated = row['target_text']

        try:
            final_eval = judge.evaluate(source, translated, reference=translated)
        except Exception as e:
            print(f"Error evaluating row {idx}: {e}")
            final_eval = {"scores": {"normalized_total": None}}

        norm_score = final_eval.get("scores", {}).get("normalized_total", None)
        normalized_scores[idx] = norm_score

        print("\n--- FINAL EVALUATION ---")
        print(json.dumps(final_eval, indent=2, ensure_ascii=False))

    # Update dataframe column for this batch
    val_df_with_scores.iloc[batch_start:batch_end, val_df_with_scores.columns.get_loc('normalized_total')] = normalized_scores[batch_start:batch_end]


    # Save intermediate results
    val_df_with_scores.to_csv('validation_with_normalized_scores_partial.csv', index=False, encoding='utf-8-sig')
    print(f"Saved partial results up to row {batch_end - 1}")

print("Batch processing complete!")

# Save final results
val_df_with_scores['normalized_total'] = normalized_scores
val_df_with_scores.to_csv('validation_with_normalized_scores_final.csv', index=False, encoding='utf-8-sig')
print("Saved final results as validation_with_normalized_scores_final.csv")
# Out:
# Last completed index on full df: 9
# Processing rows 10 to 19...
# Evaluating: "I didn’t want to go to the dentist, but I had to bite the bullet and get it over with." → "Ayoko sanang pumunta sa dentista, pero kailangan kong tiisin ito para matapos na."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 1
# Explanation: The translation is highly accurate. "Ayoko sanang pumunta sa dentista" perfectly captures the reluctance in "I didn’t want to go to the dentist." The idiom "bite the bullet" is appropriately translated into its meaning, which is to endure a difficult situation. "Kailangan kong tiisin ito" (I need to endure this) combined with "para matapos na" (so it will be over with) effectively conveys the entire meaning of "I had to bite the bullet and get it over with." All details and the overall sentiment are preserved.
#
# LanguageTool found 0 errors.
# LanguageTool detected 0 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 1
# Explanation: The translation is perfectly fluent and natural in Tagalog. It correctly captures the source's meaning, including the idiomatic expression. Instead of a literal (and incorrect) translation of "bite the bullet," it uses the phrase "kailangan kong tiisin ito" (I have to endure it), which is the correct contextual meaning. The entire sentence flows smoothly and is exactly how a native speaker would express this idea.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translation perfectly maintains the logical flow of the source sentence. It starts with the reluctance ("Ayoko sanang pumunta sa dentista"), introduces the contrast and necessity ("pero kailangan kong"), describes the action of endurance ("tiisin ito"), and concludes with the reason or goal ("para matapos na"). The flow of ideas is coherent and directly mirrors the structure of the original.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 1
# Explanation: The translation is culturally appropriate. The English idiom "bite the bullet" does not have a direct literal equivalent in Tagalog. The translator correctly chose to convey the *meaning* of the idiom—to endure a difficult but necessary situation. The phrase "kailangan kong tiisin ito para matapos na" (I have to endure this to get it over with) is a natural and accurate way to express this sentiment in Tagalog, perfectly capturing the original's tone and intent without harming the meaning.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 1
# Explanation: The translation adheres to domain rules. It correctly translates the English idiom "bite the bullet" into its semantic equivalent in Filipino, "tiisin ito" (to endure it). This is the correct stylistic choice, as a literal translation would be unnatural. The overall terminology and style are appropriate and accurately convey the meaning of the source sentence.
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated sentence is identical to the reference sentence. No information is missing or altered.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is of exceptional quality, earning a perfect score across all categories. Its key strength is the handling of the English idiom \"bite the bullet.\" Instead of an incorrect literal translation, it conveys the idiom's true meaning—to endure a difficult situation—with the perfectly natural and appropriate Tagalog phrase \"kailangan kong tiisin ito para matapos na\" (I have to endure this to get it over with). The translation accurately captures the initial reluctance expressed in the source sentence and maintains a coherent, logical flow. The result is a completely fluent and culturally appropriate sentence that a native speaker would use, with no information lost."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is of exceptional quality, earning a perfect score across all categories. Its key strength is the handling of the English idiom \"bite the bullet.\" Instead of an incorrect literal translation, it conveys the idiom's true meaning—to endure a difficult situation—with the perfectly natural and appropriate Tagalog phrase \"kailangan kong tiisin ito para matapos na\" (I have to endure this to get it over with). The translation accurately captures the initial reluctance expressed in the source sentence and maintains a coherent, logical flow. The result is a completely fluent and culturally appropriate sentence that a native speaker would use, with no information lost."
# }
# Evaluating: "Mark accidentally let the cat out of the bag about the surprise trip." → "Hindi sinasadyang nailabas ni Mark ang pusa mula sa maleta tungkol sa surprise trip."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 0
# Explanation: The translation is inaccurate because it translates the English idiom "let the cat out of the bag" literally. The source sentence means Mark accidentally revealed a secret. The translated sentence means Mark literally took a physical cat out of a bag ("nailabas ... ang pusa mula sa maleta"), which completely changes the meaning. A correct translation would convey the idea of revealing a secret, such as "Hindi sinasadyang naibunyag ni Mark ang tungkol sa surprise trip."
#
# LanguageTool found 3 errors.
# LanguageTool detected 3 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 0
# Explanation: The translation is a literal, word-for-word translation of the English idiom "let the cat out of the bag." In Filipino, "nailabas ang pusa mula sa maleta" (let the cat out of the suitcase) has no idiomatic meaning and sounds completely unnatural and nonsensical in this context. A fluent, natural translation would convey the meaning of revealing a secret, for example: "Hindi sinasadyang naibunyag ni Mark ang tungkol sa surprise trip." Because the translated sentence uses a failed literal translation of an idiom, it is not fluent.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 0
# Explanation: The translation is incoherent because it translates the English idiom "let the cat out of the bag" literally. In Filipino, "nailabas ang pusa mula sa maleta" means to physically take a cat out of a suitcase. This creates a nonsensical and illogical sentence, as the act of taking a cat out of a suitcase has no logical connection to revealing a secret about a surprise trip. The intended meaning of the source sentence is completely lost.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 0
# Explanation: The translation is a literal, word-for-word interpretation of the English idiom "let the cat out of the bag." This idiom does not exist in Filipino with the same meaning. A Filipino reader would interpret the sentence literally (Mark physically took a cat out of a bag), which makes no sense in the context and completely fails to convey the intended meaning of accidentally revealing a secret. A culturally appropriate translation would use a Filipino equivalent, such as "Hindi sinasadyang nabuking ni Mark ang tungkol sa surprise trip." The current translation harms the meaning by replacing an idiomatic expression with a nonsensical literal one.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 0
# Explanation: The translation fails because it provides a literal translation of the English idiom "let the cat out of the bag." In Filipino, "nailabas ang pusa mula sa maleta" (let the cat out of the suitcase) is nonsensical and does not carry the intended meaning of "revealing a secret." This is a major violation of translation style/domain rules, which require idioms to be translated with their meaning, not their literal words. A correct translation would use a phrase like "nabuking ni Mark" or "nasabi ni Mark ang sikreto."
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is identical to the reference text. No information is missing or altered.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 0,
#     "fluency": 0,
#     "coherence": 0,
#     "cultural_appropriateness": 0,
#     "guideline_adherence": 0,
#     "completeness": 1,
#     "total": 1,
#     "normalized_total": 1,
#     "label": "poor"
#   },
#   "explanation": "The translation is critically flawed due to a literal, word-for-word translation of the English idiom 'let the cat out of the bag.' This single error results in a score of zero for most criteria. The translation is **inaccurate** because it completely changes the intended meaning from 'revealing a secret' to the nonsensical literal action of taking a physical cat from a bag. Consequently, it is **unfluent** and **incoherent**, as the resulting Filipino phrase ('nailabas... ang pusa mula sa maleta') is unnatural, has no idiomatic meaning, and is logically disconnected from the context of a surprise trip. It is also **culturally inappropriate** because the English idiom does not exist in Filipino, leading to confusion. This literal interpretation is a major **guideline violation**, as idioms must be translated by their meaning (e.g., 'naibunyag ang sikreto' or 'nabuking'), not their words. While the translation is 'complete' in that it represents all parts of the source text, the utter failure to convey the correct meaning makes it a very poor translation."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 0,
#     "fluency": 0,
#     "coherence": 0,
#     "cultural_appropriateness": 0,
#     "guideline_adherence": 0,
#     "completeness": 1,
#     "total": 1,
#     "normalized_total": 1,
#     "label": "poor"
#   },
#   "explanation": "The translation is critically flawed due to a literal, word-for-word translation of the English idiom 'let the cat out of the bag.' This single error results in a score of zero for most criteria. The translation is **inaccurate** because it completely changes the intended meaning from 'revealing a secret' to the nonsensical literal action of taking a physical cat from a bag. Consequently, it is **unfluent** and **incoherent**, as the resulting Filipino phrase ('nailabas... ang pusa mula sa maleta') is unnatural, has no idiomatic meaning, and is logically disconnected from the context of a surprise trip. It is also **culturally inappropriate** because the English idiom does not exist in Filipino, leading to confusion. This literal interpretation is a major **guideline violation**, as idioms must be translated by their meaning (e.g., 'naibunyag ang sikreto' or 'nabuking'), not their words. While the translation is 'complete' in that it represents all parts of the source text, the utter failure to convey the correct meaning makes it a very poor translation."
# }
# Evaluating: "I won’t be able to attend the meeting later because I’m feeling under the weather." → "Hindi ako makakadalo sa meeting mamaya dahil masama ang pakiramdam ko."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 1
# Explanation: The translation is a perfect and natural-sounding equivalent of the source sentence. "Hindi ako makakadalo" correctly translates "I won't be able to attend," and "masama ang pakiramdam ko" is the standard Filipino phrase for "feeling under the weather." All details and the overall meaning are accurately conveyed.
#
# LanguageTool found 2 errors.
# LanguageTool detected 2 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 1
# Explanation: The translation is perfectly fluent and natural. It is exactly how a native Filipino speaker would phrase this sentence. "Masama ang pakiramdam ko" is the standard and idiomatic way to say "I'm feeling under the weather." The use of the English word "meeting" is also very common and natural in modern Tagalog/Filipino (Taglish). The grammar and sentence structure are flawless.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translated sentence is perfectly coherent. It follows the same logical structure as the source: a statement of inability ("Hindi ako makakadalo sa meeting mamaya") followed by a clear reason ("dahil masama ang pakiramdam ko"). The cause-and-effect relationship is clear and the sentence flows logically.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 1
# Explanation: The translation is culturally appropriate. The English idiom "feeling under the weather" is translated to its direct and most common Filipino equivalent, "masama ang pakiramdam ko." This is the natural and standard way a Filipino speaker would express that they are feeling unwell. The tone is appropriate for informing someone of an absence, and the meaning is perfectly preserved.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 1
# Explanation: The translation adheres to domain rules for terminology and style. It correctly translates the English idiom "feeling under the weather" into its natural and standard Filipino equivalent, "masama ang pakiramdam ko." The use of the loanword "meeting" is also stylistically appropriate for the context.
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is identical to the reference text. All information from the reference is present in the translation.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a perfect and natural-sounding equivalent of the source text. It accurately conveys the meaning, correctly translating the idiom \"feeling under the weather\" to its standard Filipino equivalent, \"masama ang pakiramdam ko.\" The phrasing is fluent and idiomatic, precisely how a native speaker would communicate this information. The use of the loanword \"meeting\" is common and stylistically appropriate in modern Filipino. The sentence maintains the original's logical structure, making it perfectly coherent and culturally appropriate."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a perfect and natural-sounding equivalent of the source text. It accurately conveys the meaning, correctly translating the idiom \"feeling under the weather\" to its standard Filipino equivalent, \"masama ang pakiramdam ko.\" The phrasing is fluent and idiomatic, precisely how a native speaker would communicate this information. The use of the loanword \"meeting\" is common and stylistically appropriate in modern Filipino. The sentence maintains the original's logical structure, making it perfectly coherent and culturally appropriate."
# }
# Evaluating: "Darkness is not heresy. It lies within us all." → "Hindi kasalanan ang kadiliman. Nagsisinungaling ito sa loob natin."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 0
# Explanation: The translation is inaccurate due to a critical error in word choice. The English verb "to lie" has two meanings: to be in a resting position (e.g., "it lies within us") and to tell an untruth (e.g., "he is lying"). The source uses the first meaning, "to exist" or "to reside." The translation uses "Nagsisinungaling," which corresponds to the second meaning, "to tell an untruth." This completely changes the meaning of the sentence from "Darkness exists within us all" to "It (darkness) is telling a lie inside us." A correct translation would be "Ito ay nananahan sa loob nating lahat."
#
# LanguageTool found 0 errors.
# LanguageTool detected 0 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 0
# Explanation: The translation of the second clause is a major error. The English verb "to lie" in the sense of "to be situated" or "to reside" was incorrectly translated as "nagsisinungaling," which means "to tell a lie" (to be untruthful). This completely changes the meaning of the source text and makes the sentence sound unnatural and nonsensical in this context. A fluent translation would use a phrase like "Nananahan ito sa loob natin" or "Nasa loob natin ito."
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 0
# Explanation: The translation is incoherent due to a critical mistranslation. The source word "lies" means "resides" or "is present." The translation uses "nagsisinungaling," which means "is telling lies" or "is being untruthful." This changes the logical flow. The source makes a statement and then clarifies its location ("Darkness isn't heresy; it's within us."). The translation makes a statement and then follows it with a seemingly contradictory action ("Darkness isn't a sin; it is telling lies within us."), which disrupts the logical coherence of the original thought.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 0
# Explanation: The translation is culturally inappropriate because it contains a critical mistranslation that fundamentally alters the meaning of the source text. The English verb "lies" in "it lies within us" means "resides" or "is situated." The translator has incorrectly interpreted this as "tells an untruth," translating it to the Tagalog verb "nagsisinungaling."
#
# The original quote is a philosophical statement about accepting "darkness" as an inherent part of human nature. The translation warps this into a statement that "darkness" is actively deceiving us from within. This complete change in meaning makes the translation inappropriate. A correct translation for the second sentence would be, "Ito ay nananahan sa loob nating lahat."
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 0
# Explanation: The translation violates the guideline due to a critical terminology error. The English verb "lies" in the phrase "It lies within us all" means "resides" or "exists". The translation incorrectly used "nagsisinungaling," which means "to tell a lie." This fundamentally changes the meaning of the sentence from "darkness is a part of us" to "darkness tells lies inside of us." This is a significant mistranslation of a key term. A more accurate translation would be "Nanahan ito sa loob nating lahat."
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is identical to the reference text. No information from the reference has been missed or altered.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 0,
#     "fluency": 0,
#     "coherence": 0,
#     "cultural_appropriateness": 0,
#     "guideline_adherence": 0,
#     "completeness": 0,
#     "total": 0,
#     "normalized_total": 1,
#     "label": "poor"
#   },
#   "explanation": "The translation contains a single, critical error that renders it incorrect across all dimensions. The English verb \"to lie\" has two meanings: 1) to be situated or to reside, and 2) to tell an untruth. The source text uses the first meaning, indicating that darkness \"resides\" within us.\n\nThe translation, however, uses \"nagsisinungaling,\" which corresponds to the second meaning, \"to tell a lie.\" This fundamental mistranslation completely changes the original's philosophical statement. Instead of conveying that darkness is an inherent part of us (\"It lies within us\"), the translation incorrectly states that darkness is actively deceiving us (\"It is telling lies within us\").\n\nThis error makes the translation inaccurate, incoherent, and unnatural-sounding (lacking fluency). It also changes the core message, making it culturally and contextually inappropriate. Because the intended meaning is completely lost, the translation is not complete."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 0,
#     "fluency": 0,
#     "coherence": 0,
#     "cultural_appropriateness": 0,
#     "guideline_adherence": 0,
#     "completeness": 0,
#     "total": 0,
#     "normalized_total": 1,
#     "label": "poor"
#   },
#   "explanation": "The translation contains a single, critical error that renders it incorrect across all dimensions. The English verb \"to lie\" has two meanings: 1) to be situated or to reside, and 2) to tell an untruth. The source text uses the first meaning, indicating that darkness \"resides\" within us.\n\nThe translation, however, uses \"nagsisinungaling,\" which corresponds to the second meaning, \"to tell a lie.\" This fundamental mistranslation completely changes the original's philosophical statement. Instead of conveying that darkness is an inherent part of us (\"It lies within us\"), the translation incorrectly states that darkness is actively deceiving us (\"It is telling lies within us\").\n\nThis error makes the translation inaccurate, incoherent, and unnatural-sounding (lacking fluency). It also changes the core message, making it culturally and contextually inappropriate. Because the intended meaning is completely lost, the translation is not complete."
# }
# Evaluating: "This would be easier if blood came in more colours." → "Ito ay magiging mas madali kung ang dugo ay dumating sa mas maraming kulay."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 1
# Explanation: The translation is a literal and accurate rendering of the source sentence. All key concepts are correctly translated and the overall meaning is preserved.
#
# LanguageTool found 0 errors.
# LanguageTool detected 0 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 0
# Explanation: The phrase "dumating sa mas maraming kulay" is a very literal and unnatural translation of the English phrasal verb "came in more colours." In Tagalog, objects don't "arrive in" colors. A fluent speaker would phrase this differently, for example: "...kung may iba't ibang kulay ang dugo" (if blood had different colors) or "...kung mas maraming kulay ang dugo" (if blood had more colors). The use of "dumating" (arrived) in this context is unidiomatic and makes the sentence sound awkward.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translated sentence is coherent. It correctly forms a conditional statement in Tagalog, preserving the logical flow of the original English sentence. The cause-and-effect relationship is clear and grammatically sound.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 0
# Explanation: The translation is too literal and sounds unnatural in Tagalog. The phrase "dumating sa" is a direct translation of "came in," but "dumating" means "to arrive." In this context, it makes it sound as if the blood is a delivery that arrived in different colors. A more natural and appropriate phrasing would be "kung may iba't ibang kulay ang dugo" (if blood has different colors) or "kung ang dugo ay may mas maraming kulay" (if blood has more colors). The chosen form differs in a way that harms the naturalness and meaning of the sentence.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 0
# Explanation: The translation is too literal. The phrase "came in" from the source is an idiom meaning "existed in" or "was available in." The chosen Tagalog verb "dumating" literally means "arrived," which is unnatural and awkward in this context. It makes it sound as if blood is a physical object that "arrives." A more natural and idiomatic translation would be "...kung may mas maraming kulay ang dugo" (...if blood had more colors) or "...kung iba-iba ang kulay ng dugo" (...if the color of blood was varied). The use of "dumating" is a stylistic violation.
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is identical to the reference text. All information from the reference is present.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 0,
#     "coherence": 1,
#     "cultural_appropriateness": 0,
#     "guideline_adherence": 0,
#     "completeness": 1,
#     "total": 3,
#     "normalized_total": 3,
#     "label": "good"
#   },
#   "explanation": "While the translation is a complete and literally accurate rendering of the source text, and maintains a coherent sentence structure, it suffers significantly from a major fluency issue. The core problem is the overly literal translation of the English phrasal verb \"came in\" to the Tagalog \"dumating sa.\" In Tagalog, \"dumating\" means \"to arrive,\" which is completely unnatural and unidiomatic in the context of an object having colors. This makes the sentence sound awkward, as if blood is a delivery that arrived in multiple colors. A fluent, culturally appropriate, and idiomatic translation would use phrases like \"kung may iba't ibang kulay ang dugo\" (if blood had different colors) or \"kung mas maraming kulay ang dugo\" (if blood had more colors). This literalism is a stylistic violation that harms the naturalness of the translation, causing it to fail on fluency, cultural appropriateness, and guideline adherence."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 0,
#     "coherence": 1,
#     "cultural_appropriateness": 0,
#     "guideline_adherence": 0,
#     "completeness": 1,
#     "total": 3,
#     "normalized_total": 3,
#     "label": "good"
#   },
#   "explanation": "While the translation is a complete and literally accurate rendering of the source text, and maintains a coherent sentence structure, it suffers significantly from a major fluency issue. The core problem is the overly literal translation of the English phrasal verb \"came in\" to the Tagalog \"dumating sa.\" In Tagalog, \"dumating\" means \"to arrive,\" which is completely unnatural and unidiomatic in the context of an object having colors. This makes the sentence sound awkward, as if blood is a delivery that arrived in multiple colors. A fluent, culturally appropriate, and idiomatic translation would use phrases like \"kung may iba't ibang kulay ang dugo\" (if blood had different colors) or \"kung mas maraming kulay ang dugo\" (if blood had more colors). This literalism is a stylistic violation that harms the naturalness of the translation, causing it to fail on fluency, cultural appropriateness, and guideline adherence."
# }
# Evaluating: "This guy right here is Shadow, and he's kinda my biggest rival. He's also a real buzz-kill." → "Ang lalaking ito dito ay si Shadow, at siya ang aking pinakamalaking karibal. Isa rin siyang totoong buzz-kill."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 0
# Explanation: The translation omits the word "kinda" ("kinda my biggest rival"). This omission changes the meaning by removing the casual, slightly hesitant, or softening tone of the original statement, making the translated version more direct and assertive than the source.
#
# LanguageTool found 4 errors.
# LanguageTool detected 4 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 0
# Explanation: The translation is not fluent because it literally translates an English idiom without finding a proper Tagalog equivalent. The term "buzz-kill" is not a common loanword in Filipino. A fluent translation would use a phrase like "panira ng kasiyahan" or the more common slang "KJ" (from killjoy). The phrase "Ang lalaking ito dito" is also a bit clunky and unnatural-sounding; "Itong lalaking 'to" would be more conversational and fluent.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translation maintains the logical flow of the source sentence perfectly. It first introduces the character ("Ang lalaking ito dito ay si Shadow"), then describes his relationship to the speaker ("at siya ang aking pinakamalaking karibal"), and finally adds another characteristic ("Isa rin siyang totoong buzz-kill"). The use of "at" (and) and "rin" (also) correctly connects these ideas in the same sequence as the original.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 1
# Explanation: The translation is culturally appropriate. It uses the English term "buzz-kill" within the Tagalog sentence. This practice, known as code-switching or "Taglish," is extremely common in the Philippines, especially in informal and conversational contexts. Translating the idiom literally might have sounded unnatural or overly formal, so retaining the English term is a good choice to preserve the casual tone of the original source.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 1
# Explanation: The translation is accurate. The use of the English term "buzz-kill" is an example of code-switching, which is very common in modern Filipino and is stylistically appropriate for the informal tone of the source. It does not violate domain rules for this type of content.
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is identical to the reference text. All information from the reference is present in the translation.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 0,
#     "fluency": 0,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 4,
#     "normalized_total": 3,
#     "label": "good"
#   },
#   "explanation": "The analyses present a conflicting assessment of the translation. On one hand, the translation is praised for its logical flow (Coherence) and its use of code-switching (\"buzz-kill\"), which is presented as culturally appropriate (Cultural Appropriateness, Guideline Adherence). \n\nHowever, there are significant and contradictory flaws noted. The translation is deemed inaccurate for omitting the word \"kinda,\" which alters the original's casual tone, making the translation more assertive than intended. This omission also contradicts the Completeness score, which incorrectly states the translation is identical to the reference. \n\nFurthermore, the translation is rated as not fluent due to the clunky phrasing \"Ang lalaking ito dito\" and the use of \"buzz-kill,\" which is described as an uncommon loanword, contrasting directly with the cultural appropriateness assessment. The fluency analysis provides better local equivalents like \"panira ng kasiyahan\" or \"KJ.\" \n\nOverall, the critical errors in accuracy (omitting \"kinda\") and fluency (unnatural phrasing) outweigh the positive aspects, making it a flawed translation."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 0,
#     "fluency": 0,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 4,
#     "normalized_total": 3,
#     "label": "good"
#   },
#   "explanation": "The analyses present a conflicting assessment of the translation. On one hand, the translation is praised for its logical flow (Coherence) and its use of code-switching (\"buzz-kill\"), which is presented as culturally appropriate (Cultural Appropriateness, Guideline Adherence). \n\nHowever, there are significant and contradictory flaws noted. The translation is deemed inaccurate for omitting the word \"kinda,\" which alters the original's casual tone, making the translation more assertive than intended. This omission also contradicts the Completeness score, which incorrectly states the translation is identical to the reference. \n\nFurthermore, the translation is rated as not fluent due to the clunky phrasing \"Ang lalaking ito dito\" and the use of \"buzz-kill,\" which is described as an uncommon loanword, contrasting directly with the cultural appropriateness assessment. The fluency analysis provides better local equivalents like \"panira ng kasiyahan\" or \"KJ.\" \n\nOverall, the critical errors in accuracy (omitting \"kinda\") and fluency (unnatural phrasing) outweigh the positive aspects, making it a flawed translation."
# }
# Evaluating: "Stealth is not your thing. But it's adorable you're willing to try." → "Ang pagnanakaw ay hindi bagay sa iyo. Ngunit ito ay kaibig-ibig na handa kang subukan."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 0
# Explanation: The translation is inaccurate because it mistakes the word "stealth" for "stealing." "Stealth" refers to the quality of being sneaky, quiet, or unobserved. The translation uses "pagnanakaw," which specifically means "theft" or "stealing." This changes the original meaning from "You are not good at being sneaky" to "The act of stealing is not for you," which is a significant difference.
#
# LanguageTool found 2 errors.
# LanguageTool detected 2 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 0
# Explanation: The translation is grammatically structured correctly, but it is not fluent because of a critical mistranslation that makes the sentence unnatural and nonsensical. The word "stealth" was translated to "pagnanakaw," which means "theft" or "stealing." While a thief might use stealth, the two words are not synonymous.
#
# The resulting sentence, "Stealing is not for you. But it's adorable you're willing to try," creates a bizarre and unnatural combination of ideas. Accusing someone of attempting theft and then calling that attempt "adorable" is tonally jarring and not something a fluent speaker would say. The incorrect word choice renders the entire statement unnatural and therefore not fluent.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 0
# Explanation: The translation is incoherent due to a critical mistranslation. "Stealth" was translated as "pagnanakaw," which means "stealing." The source sentence has a clear logical flow: a person is not good at being stealthy, but their attempt is endearing. The translated sentence, however, says: "Stealing is not for you. But it's adorable you're willing to try." Praising an attempt at stealing as "adorable" is illogical and nonsensical in most contexts, breaking the logical cohesion of the sentence.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 0
# Explanation: The translation is culturally and contextually inappropriate due to a critical mistranslation. The word "stealth" was translated to "pagnanakaw," which specifically means "stealing" or "thievery."
#
# "Stealth" in the source context refers to the quality of being quiet, sneaky, or subtle, and is used in a light-hearted, teasing manner. "Pagnanakaw," however, is a serious accusation of a criminal act.
#
# This error completely changes the tone and meaning of the sentence. The original is an affectionate tease about someone being clumsy. The translation becomes a bizarre and serious statement accusing someone of being a bad thief, which is culturally inappropriate and nonsensical in the original context. This is a severe harm to the meaning.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 0
# Explanation: The translation violates terminology rules. "Stealth" was translated to "pagnanakaw." "Stealth" refers to the quality of being sneaky or moving without being detected. "Pagnanakaw" specifically means "theft" or "stealing." This is a significant mistranslation that changes the meaning of the sentence from a comment on someone's lack of subtlety to an accusation of being a bad thief. A more accurate translation for "stealth" would be "pagiging palihim" or "pagkilos nang patago."
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 0
# Explanation: The translation alters a key piece of information from the source. The word "Stealth" was translated as "pagnanakaw," which means "stealing" or "theft." "Stealth" refers to the act of moving secretly and quietly to avoid detection, which is not the same as stealing. This fundamental change in meaning makes the translation an incomplete or inaccurate representation of the source sentence.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 0,
#     "fluency": 0,
#     "coherence": 0,
#     "cultural_appropriateness": 0,
#     "guideline_adherence": 0,
#     "completeness": 0,
#     "total": 0,
#     "normalized_total": 1,
#     "label": "poor"
#   },
#   "explanation": "The translation suffers from a single, critical error that causes it to fail across all quality dimensions: it mistranslates the word \"stealth\" as \"pagnanakaw,\" which means \"stealing\" or \"theft.\" This fundamentally changes the meaning and tone of the source text.\n\nThe original sentence is a light-hearted tease about someone being bad at being sneaky. By changing \"stealth\" to \"stealing,\" the translation becomes an inaccurate and bizarre statement accusing someone of attempting a crime and then calling that attempt \"adorable.\" This creates an illogical and incoherent combination of ideas that a fluent speaker would not produce. The shift from a playful comment to a serious accusation of a criminal act makes the translation contextually and culturally inappropriate. This severe mistranslation of a key term violates terminology guidelines and results in an incomplete representation of the original message."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 0,
#     "fluency": 0,
#     "coherence": 0,
#     "cultural_appropriateness": 0,
#     "guideline_adherence": 0,
#     "completeness": 0,
#     "total": 0,
#     "normalized_total": 1,
#     "label": "poor"
#   },
#   "explanation": "The translation suffers from a single, critical error that causes it to fail across all quality dimensions: it mistranslates the word \"stealth\" as \"pagnanakaw,\" which means \"stealing\" or \"theft.\" This fundamentally changes the meaning and tone of the source text.\n\nThe original sentence is a light-hearted tease about someone being bad at being sneaky. By changing \"stealth\" to \"stealing,\" the translation becomes an inaccurate and bizarre statement accusing someone of attempting a crime and then calling that attempt \"adorable.\" This creates an illogical and incoherent combination of ideas that a fluent speaker would not produce. The shift from a playful comment to a serious accusation of a criminal act makes the translation contextually and culturally inappropriate. This severe mistranslation of a key term violates terminology guidelines and results in an incomplete representation of the original message."
# }
# Evaluating: "Cheddar cheese got its name from a village in what country?" → "Ang nayon na pinagkuhanan ng pangalan ng cheddar cheese ay nasaang bansa?"
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 1
# Explanation: The translation is a perfect and natural-sounding equivalent of the source sentence. It accurately captures all the key elements: "Cheddar cheese," "got its name from," "a village," and "in what country?" The meaning is fully preserved.
#
# LanguageTool found 4 errors.
# LanguageTool detected 4 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 1
# Explanation: The translation is grammatically correct, natural, and idiomatic. The structure is clear, and the word choices ("pinagkuhanan", "nasaang") are perfectly suited for the context. It reads like a sentence a native speaker would produce. The potential errors flagged by LanguageTool are likely false positives, as the sentence is fluent.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translation is a perfectly coherent and natural-sounding question in Filipino. The logical flow is maintained, accurately conveying the original English question's intent.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 1
# Explanation: The translation is culturally appropriate. The tone is neutral and inquisitive, matching the source. The phrasing "pinagkuhanan ng pangalan" is a natural and accurate way to express "got its name from" in Tagalog. The overall structure is standard for a Tagalog question and conveys the original meaning perfectly without any awkwardness or cultural mismatch.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 1
# Explanation: The translation adheres to domain rules. The terminology used is accurate and natural-sounding in Tagalog. "Pinagkuhanan ng pangalan" is an excellent translation for "got its name from," and "nasaang bansa?" is the correct way to ask "in what country?". The style matches the source, which is a straightforward question.
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is identical to the reference text. No information has been omitted or altered.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a perfect and natural-sounding equivalent of the source sentence. It accurately captures all key elements and is grammatically correct, fluent, and idiomatic. The phrasing, such as \"pinagkuhanan ng pangalan\" for \"got its name from,\" is perfectly suited for the context. The translation maintains the original's inquisitive tone, is culturally appropriate, and is identical to the reference text, making it a complete and flawless rendering."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a perfect and natural-sounding equivalent of the source sentence. It accurately captures all key elements and is grammatically correct, fluent, and idiomatic. The phrasing, such as \"pinagkuhanan ng pangalan\" for \"got its name from,\" is perfectly suited for the context. The translation maintains the original's inquisitive tone, is culturally appropriate, and is identical to the reference text, making it a complete and flawless rendering."
# }
# Evaluating: "Which of the following tools is LEAST likely to be used in the process of creating a wood sculpture?" → "Alin sa mga sumusunod ang PINAKABIHIRANG ginagamit sa paggawa ng eskulturang kahoy?"
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 1
# Explanation: The translation is accurate. "Alin sa mga sumusunod" correctly translates to "Which of the following". "PINAKABIHIRANG ginagamit" is a perfect translation for "LEAST likely to be used" (most rarely used). "sa paggawa ng eskulturang kahoy" accurately means "in the process of creating a wood sculpture". The meaning is fully preserved.
#
# LanguageTool found 2 errors.
# LanguageTool detected 2 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 1
# Explanation: The translation is grammatically correct, accurate, and uses natural Filipino phrasing. "Pinakabihirang ginagamit" is an excellent and idiomatic way to convey "least likely to be used" in this context. The sentence structure is standard and flows smoothly.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translated sentence perfectly maintains the logical flow of the source. It correctly structures the question in Tagalog, starting with the interrogative phrase "Alin sa mga sumusunod" (Which of the following), followed by the specific condition "ang PINAKABIHIRANG ginagamit" (is LEAST likely to be used), and ending with the context "sa paggawa ng eskulturang kahoy" (in the process of creating a wood sculpture). The structure is logical, natural, and presents the same coherent thought as the original English sentence.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 1
# Explanation: The translation is culturally appropriate. The phrase "LEAST likely" is expertly translated to "PINAKABIHIRANG," which is the superlative form of "bihira" (rare/seldom). In this context, "rarest/most seldom used" is a perfect and natural-sounding equivalent to "least likely to be used." The rest of the sentence is a direct and accurate translation. The tone and meaning are fully preserved without any awkwardness.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 1
# Explanation: The translation is excellent. "Pinakabihirang ginagamit" is a very accurate and natural way to express "least likely to be used" in this context. "Eskulturang kahoy" is the correct term for "wood sculpture." All terminology is appropriate for the domain and the style is fitting for a question format. The capitalization of "PINAKABIHIRANG" also correctly reflects the emphasis on "LEAST" in the source.
#
#
# ...
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is identical to the reference text. No information has been omitted or altered.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 0,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 5,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a complete and literal rendering of the source, accurately capturing the meaning of each clause and maintaining a coherent, logical flow. The concepts are culturally appropriate. However, the translation suffers from a significant fluency issue. The final clause, \"at kung saan ito dapat nasa,\" is grammatically awkward and sounds unnatural in Filipino. The locative word \"nasa\" (is at/in) feels incomplete without a specific location following it, making the sentence unidiomatic. More fluent alternatives, such as \"...at kung saan ito nararapat\" (and where it belongs), would be more natural."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 0,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 5,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a complete and literal rendering of the source, accurately capturing the meaning of each clause and maintaining a coherent, logical flow. The concepts are culturally appropriate. However, the translation suffers from a significant fluency issue. The final clause, \"at kung saan ito dapat nasa,\" is grammatically awkward and sounds unnatural in Filipino. The locative word \"nasa\" (is at/in) feels incomplete without a specific location following it, making the sentence unidiomatic. More fluent alternatives, such as \"...at kung saan ito nararapat\" (and where it belongs), would be more natural."
# }
# Evaluating: "Sick of tea?! That's like being sick of breathing!" → "Ayaw mo na ng tsaa?! Parang sinabi mo na ring sawa ka nang huminga!"
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 1
# Explanation: The translation is a perfect and natural-sounding equivalent of the source. "Ayaw mo na ng tsaa?!" captures the sentiment of being "sick of tea" (not wanting it anymore). The second clause, "Parang sinabi mo na ring sawa ka nang huminga!", accurately translates the hyperbolic comparison "That's like being sick of breathing!". The meaning, tone, and incredulity are all preserved.
#
# LanguageTool found 1 errors.
# LanguageTool detected 1 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 1
# Explanation: The translation is perfectly fluent and natural. It captures the tone and meaning of the source text using common, idiomatic Filipino expressions. "Ayaw mo na ng tsaa?!" is a natural way to express disbelief, and "Parang sinabi mo na ring sawa ka nang huminga!" is an excellent, idiomatic translation of the hyperbolic comparison. The grammar is correct and the sentence flows smoothly.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translation maintains the logical flow of the source sentence perfectly. The initial expression of disbelief ("Sick of tea?!") is followed by a hyperbolic comparison ("That's like being sick of breathing!"). This structure is mirrored exactly in the translation ("Ayaw mo na ng tsaa?! Parang sinabi mo na ring sawa ka nang huminga!"), creating a sentence that is perfectly logical and understandable in Filipino. The two parts of the sentence connect seamlessly.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 1
# Explanation: The translation is culturally appropriate. It perfectly captures the tone of disbelief and hyperbole from the source sentence using natural Filipino expressions. The phrase "Parang sinabi mo na rin..." is a very common and fitting way to frame a dramatic comparison in Tagalog, and "sawa ka nang huminga" is a direct and effective equivalent for "sick of breathing." The overall tone and meaning are preserved without any cultural missteps.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 1
# Explanation: The translation is a perfect match to the reference. It correctly uses appropriate terminology ("tsaa" for tea, "huminga" for breathing) and captures the informal, exasperated style of the source ("Parang sinabi mo na ring..."). Therefore, it fully adheres to the domain's stylistic and terminological rules as established by the reference.
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is identical to the reference text. All information from the reference is present and unaltered.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a perfect and natural-sounding Filipino equivalent, identical to the reference. It accurately captures the source's incredulous tone (\"Ayaw mo na ng tsaa?!\") and the hyperbolic comparison (\"Parang sinabi mo na ring sawa ka nang huminga!\"). The phrasing is perfectly fluent and idiomatic, using common expressions that are culturally appropriate for the context. The logical flow of the original sentence is mirrored exactly, resulting in a coherent and complete translation that fully adheres to all guidelines."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a perfect and natural-sounding Filipino equivalent, identical to the reference. It accurately captures the source's incredulous tone (\"Ayaw mo na ng tsaa?!\") and the hyperbolic comparison (\"Parang sinabi mo na ring sawa ka nang huminga!\"). The phrasing is perfectly fluent and idiomatic, using common expressions that are culturally appropriate for the context. The logical flow of the original sentence is mirrored exactly, resulting in a coherent and complete translation that fully adheres to all guidelines."
# }
# Evaluating: "I wanted to invite my youngest to go get some ice cream, if he’ll let me." → "Gusto ko imbitahin yung pinakabata kong anak para kumuha ng ice cream, kung papayagan niya ako."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 1
# Explanation: The translation is a perfect and natural-sounding equivalent of the source sentence. All components are accurately translated: "I wanted to invite" as "Gusto ko imbitahin", "my youngest" as "yung pinakabata kong anak", "to go get some ice cream" as "para kumuha ng ice cream", and "if he'll let me" as "kung papayagan niya ako". The meaning is fully preserved.
#
# LanguageTool found 3 errors.
# LanguageTool detected 3 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 0
# Explanation: The sentence is grammatically sound, but the phrase "para kumuha ng ice cream" is an unnatural and overly literal translation of "to go get some ice cream." A more fluent and idiomatic way to say this in Filipino would be "para kumain ng ice cream" (to eat ice cream) or "para mag-ice cream" (to have ice cream). The use of "kumuha" (to get/take) sounds slightly awkward in this context, making the sentence less natural.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translated sentence is perfectly coherent. The logical flow is identical to the source: the main clause expresses a desire, followed by the purpose of the action, and concludes with a conditional clause. The sentence makes complete sense in Tagalog.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 1
# Explanation: The translation is culturally appropriate. It correctly captures the tone of a parent gently asking their child, acknowledging the child's autonomy. The phrase "kung papayagan niya ako" is a direct and natural equivalent of "if he'll let me" in a Filipino context. The wording is standard and reflects a common and respectful way of speaking.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 1
# Explanation: The translation adheres to the domain's terminology and style. It is a natural and accurate translation of the source sentence into conversational Tagalog.
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is identical to the reference text. No information from the reference is missing or altered.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 0,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 5,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is largely accurate, coherent, and culturally appropriate, successfully conveying the intended meaning. However, it lacks fluency due to the phrase \"para kumuha ng ice cream,\" which is an overly literal and unnatural translation of \"to go get some ice cream.\" A more idiomatic and common Filipino expression would be \"para kumain ng ice cream\" (to eat ice cream) or \"para mag-ice cream\" (to have ice cream). This awkward phrasing makes the sentence sound less natural, despite being grammatically correct and understandable."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 0,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 5,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is largely accurate, coherent, and culturally appropriate, successfully conveying the intended meaning. However, it lacks fluency due to the phrase \"para kumuha ng ice cream,\" which is an overly literal and unnatural translation of \"to go get some ice cream.\" A more idiomatic and common Filipino expression would be \"para kumain ng ice cream\" (to eat ice cream) or \"para mag-ice cream\" (to have ice cream). This awkward phrasing makes the sentence sound less natural, despite being grammatically correct and understandable."
# }
# Evaluating: "That person has no more respect or love for you, leave them." → "Wala nang respeto at pagmamahal yung tao para sa'yo, iwan mo na."
#
# --- Model initialized successfully. ---
#
# --- STARTING AGENTIC EVALUATION ---
#
#
# --- Agent Thought: Executing accuracy ---
# --- Agent Observation (accuracy): ---
# Score: 1
# Explanation: The translation is a perfect and natural-sounding equivalent of the source sentence. Each component is accurately translated: "Wala nang" for "no more," "respeto at pagmamahal" for "respect or love," "yung tao para sa'yo" for "that person for you," and "iwan mo na" for the command "leave them." The meaning is fully intact.
#
# LanguageTool found 0 errors.
# LanguageTool detected 0 errors in the translation.
#
# --- Agent Thought: Executing fluency ---
# --- Agent Observation (fluency): ---
# Score: 1
# Explanation: The translation is perfectly fluent. The phrasing "Wala nang respeto at pagmamahal yung tao para sa'yo" and the command "iwan mo na" are natural, common, and idiomatic in Tagalog. The sentence structure and word choice are exactly what a native speaker would use in this context.
#
#
# --- Agent Thought: Executing coherence ---
# --- Agent Observation (coherence): ---
# Score: 1
# Explanation: The translated sentence is perfectly coherent. The logical flow of the source text, which presents a reason ("That person has no more respect or love for you") followed by a resulting command ("leave them"), is perfectly maintained in the translation. The two clauses connect logically and the entire sentence is natural and easy to understand.
#
#
# --- Agent Thought: Executing cultural_appropriateness ---
# --- Agent Observation (cultural_appropriateness): ---
# Score: 1
# Explanation: The translation is culturally appropriate. It uses a natural, conversational tone that a Filipino speaker would use when giving direct, serious advice to a friend. The phrase "iwan mo na" perfectly captures the finality and urgency implied in "leave them." The language is direct without being disrespectful, fitting the context perfectly.
#
#
# --- Agent Thought: Executing guideline_adherence ---
# --- Agent Observation (guideline_adherence): ---
# Score: 1
# Explanation: The translation adheres perfectly to the style and terminology appropriate for the source text. The source is informal and direct advice, and the translation ("Wala nang respeto at pagmamahal yung tao para sa'yo, iwan mo na.") captures this tone precisely with natural, conversational Filipino. There are no violations of domain rules.
#
#
# --- Agent Thought: Executing completeness ---
# --- Agent Observation (completeness): ---
# Score: 1
# Explanation: The translated text is an exact match to the reference text. All information from the reference is present in the translation.
#
#
# --- Agent Thought: Synthesizing Final Judgment ---
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a perfect and natural-sounding equivalent of the source text, earning a flawless score. It accurately translates every component, from 'Wala nang' for 'no more' to the command 'iwan mo na' for 'leave them.' The phrasing is perfectly fluent and idiomatic, representing exactly how a native speaker would give this kind of direct, serious advice. The logical flow of the source (reason followed by a command) is maintained perfectly, and the translation is culturally appropriate in its direct yet natural tone. It adheres to all guidelines and is a complete match to the reference text."
# }
#
# --- FINAL EVALUATION ---
# {
#   "scores": {
#     "accuracy": 1,
#     "fluency": 1,
#     "coherence": 1,
#     "cultural_appropriateness": 1,
#     "guideline_adherence": 1,
#     "completeness": 1,
#     "total": 6,
#     "normalized_total": 5,
#     "label": "excellent"
#   },
#   "explanation": "The translation is a perfect and natural-sounding equivalent of the source text, earning a flawless score. It accurately translates every component, from 'Wala nang' for 'no more' to the command 'iwan mo na' for 'leave them.' The phrasing is perfectly fluent and idiomatic, representing exactly how a native speaker would give this kind of direct, serious advice. The logical flow of the source (reason followed by a command) is maintained perfectly, and the translation is culturally appropriate in its direct yet natural tone. It adheres to all guidelines and is a complete match to the reference text."
# }
# Saved partial results up to row 56
# Batch processing complete!
# Saved final results as validation_with_normalized_scores_final.csv

# %%
val_df_with_scores = pd.read_csv("validation_with_normalized_scores_final.csv")

val_df_with_scores.head()
# Out:
#                                          source_text  \
# 0  The children laughed and played under the afte...
# 1           She took a break to gather her thoughts.
# 2  The algorithm efficiently identifies patterns ...
# 3  Data normalization helps improve model perform...
# 4  alam mo ma'am masaya naman topics natin sa phi...
#
#                                          target_text  score  \
# 0  Ang mga bata ay nagtawanan at naglaro sa ilali...    4.0
# 1                Nagpahinga siya para mag-isip-isip.    4.0
# 2  Mabisang kinikilala ng algoritmo ang mga patte...    3.0
# 3  Tumutulong sa pagpabuti ng model ang normalisa...    5.0
# 4  You know, ma'am, we have a lot of fun philosop...    4.0
#
#                                  Rater 1 Explanation  \
# 0  Accurate, fluent, and natural translation. Cap...
# 1  The translation is accurate. It was able to ca...
# 2  The translation of "identifies" as "kinikilala...
# 3  The translated text is natural and captures th...
# 4  flawed translation is close, but failed to tra...
#
#                                  Rater 2 Explanation  \
# 0  Just slight error due to the literal translati...
# 1  The translation would have been better if the ...
# 2  The translation would have been better if the ...
# 3  The translation didn't literally translated th...
# 4                                                NaN
#
#                          Contributor  normalized_total
# 0  Paul Ivan Enclonar/Alonzo Rimando               3.0
# 1  Paul Ivan Enclonar/Alonzo Rimando               5.0
# 2  Paul Ivan Enclonar/Alonzo Rimando               5.0
# 3  Paul Ivan Enclonar/Alonzo Rimando               5.0
# 4                    Charibeth Cheng               1.0

# %% [markdown]
# # Data analysis

# %%
df = val_df_with_scores.dropna(subset=['score','normalized_total']).copy()

# Ensure numeric types
df['score'] = pd.to_numeric(df['score'], errors='coerce')
df['normalized_total'] = pd.to_numeric(df['normalized_total'], errors='coerce')

df = df.dropna(subset=['score','normalized_total']).reset_index(drop=True)

print(f"Using {len(df)} examples for comparison.")

# 1) Spearman correlation between raw numeric human score and LLM normalized_total
rho, pval = spearmanr(df['score'], df['normalized_total'])
print(f"\nSpearman correlation (human score vs LLM normalized_total): ρ = {rho:.3f}, p-value = {pval:.3g}")

# 2) Map numeric -> coarse labels by snapping to nearest of [1,3,5], then text label
def snap_to_coarse_label(x):
    # nearest among 1,3,5
    choices = np.array([1,3,5])
    nearest = choices[np.argmin(np.abs(choices - x))]
    label_map = {1: 'poor', 3: 'good', 5: 'excellent'}
    return nearest, label_map[int(nearest)]

df['human_nearest_score'] = df['score'].apply(lambda x: snap_to_coarse_label(x)[0])
df['human_label'] = df['score'].apply(lambda x: snap_to_coarse_label(x)[1])

# For LLM normalized_total we expect values in {1,3,5} already; map to text
label_map = {1: 'poor', 3: 'good', 5: 'excellent'}
df['llm_label'] = df['normalized_total'].map(label_map)

# 3) Label agreement
label_agreement = (df['human_label'] == df['llm_label']).mean()
print(f"\nLabel agreement (human vs LLM): {label_agreement*100:.1f}% ({int((label_agreement)*len(df))} / {len(df)})")

# Confusion matrix (counts)
confusion_counts = pd.crosstab(df['human_label'], df['llm_label'], rownames=['human'], colnames=['llm'], margins=True)
print("\nConfusion counts (human_label x llm_label):")
print(confusion_counts)

# Normalized confusion (row-normalized to see, for each human label, LLM distribution)
confusion_norm = pd.crosstab(df['human_label'], df['llm_label'], normalize='index')
print("\nConfusion (row-normalized):")
print(confusion_norm)

# 4) Top numeric disagreements (absolute diff)
df['abs_diff'] = (df['score'] - df['normalized_total']).abs()
top_disagreements = df.sort_values('abs_diff', ascending=False).head(10)
print("\nTop 10 numeric disagreements (human score vs LLM normalized_total):")
display_cols = ['source_text','target_text','score','normalized_total','human_label','llm_label','abs_diff']
print(top_disagreements[display_cols].to_string(index=False))

# 5) Quick summary
mean_abs_diff = df['abs_diff'].mean()
print(f"\nMean absolute difference (|human - llm|): {mean_abs_diff:.3f}")

df.to_csv("comparison_human_vs_llm.csv", index=False, encoding='utf-8-sig')
print("\nSaved detailed comparison to comparison_human_vs_llm.csv")
# Out:
# Using 57 examples for comparison.
#
# Spearman correlation (human score vs LLM normalized_total): ρ = 0.384, p-value = 0.00318
#
# Label agreement (human vs LLM): 35.1% (20 / 57)
#
# Confusion counts (human_label x llm_label):
# llm        excellent  good  poor  All
# human
# excellent         13     0     1   14
# good              24     3     2   29
# poor               7     3     4   14
# All               44     6     7   57
#
# Confusion (row-normalized):
# llm_label    excellent      good      poor
# human_label
# excellent     0.928571  0.000000  0.071429
# good          0.827586  0.103448  0.068966
# poor          0.500000  0.214286  0.285714
#
# Top 10 numeric disagreements (human score vs LLM normalized_total):
#                                                                                                                                                                                                                                                                                                                                       source_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                           target_text  score  normalized_total human_label llm_label  abs_diff
#                                                                                                                                                                                                                                                                                         Taking crazy things seriously is a serious waste of time.                                                                                                                                                                                                                                                                                                                                                                                                        Ang pagseseryoso ng mga bagay na baliw ay isang seryosong pag-aaksaya ng oras.    5.0               1.0   excellent      poor       4.0
# The Binding of Isaac: Rebirth is a randomly generated action RPG shooter with heavy Rogue-like elements. Following Isaac on his journey players will find bizarre treasures that change Isaac's form giving him super human abilities and enabling him to fight off droves of mysterious creatures, discover secrets and fight his way to safety. Ang The Binding of Isaac: Rebirth ay isang random na nabuong action RPG shooter na may mabibigat na elementong parang Rogue. Kasunod ni Isaac sa kanyang paglalakbay, ang mga manlalaro ay makakahanap ng mga kakaibang kayamanan na nagpabago sa anyo ni Isaac na nagbibigay sa kanya ng sobrang mga kakayahan ng tao at nagbibigay-daan sa kanya upang labanan ang napakaraming mga misteryosong nilalang, tumuklas ng mga lihim at labanan ang kanyang daan patungo sa kaligtasan.    2.0               5.0        poor excellent       3.0
#                                                                                                                                                                                                                                                                 Which of the following dental topics is developmentally appropriate for toddlers?                                                                                                                                                                                                                                                                                                                                                                                                  Alin sa mga sumusunod na paksa sa ngipin ang angkop sa pag-unlad para sa mga paslit?    2.0               5.0        poor excellent       3.0
#                                                                 Sea of Thieves is a smash-hit pirate adventure game, offering the quintessential pirate experience of plundering lost treasures, intense battles, vanquishing sea monsters and more. Dive in with this revised edition of the game, which includes access to digital bonus media.                                                                                                                                                       Ang Sea of Thieves ay isang smash-hit na pirate adventure game, na nag-aalok ng quintessential na karanasan sa pirata ng pagnanakaw sa mga nawawalang kayamanan, matinding labanan, pagtalo sa mga halimaw sa dagat at higit pa. Sumisid sa binagong edisyon ng larong ito, na kinabibilangan ng access sa digital bonus media.    2.0               5.0        poor excellent       3.0
#                                                                                                                                                                                                                                                                 The wave returns to the ocean, where it came from, and where it's supposed to be.                                                                                                                                                                                                                                                                                                                                                                                               Bumabalik ang alon sa karagatan, kung saan ito nanggaling, at kung saan ito dapat nasa.    2.0               5.0        poor excellent       3.0
#                                                                                                                                                                                                                                                                                  The kernel handles low-level operations in the operating system.                                                                                                                                                                                                                                                                                                                                                                                                        Pinangangasiwaan ng kernel ang mga low-level na operasyon sa operating system.    2.0               5.0        poor excellent       3.0
#                                                                                                                                                                                                                                                                                          The nurse inserted the IV incorrectly, causing bruising.                                                                                                                                                                                                                                                                                                                                                                                                                                 Ang nurse ay pinasok ang IV ng mali, kaya nagka-pasa.    2.0               5.0        poor excellent       3.0
#                                                                                                                                                                                                                                                                                      For so long, you and me been finding each other for so long.                                                                                                                                                                                                                                                                                                                                                                                                                         Matagal na, matagal na tayong dalawa naghahanap sa isa't isa.    2.0               5.0        poor excellent       3.0
#                                                                                                                                                                                                                                              alam mo ma'am masaya naman topics natin sa philosophy inaantok lang talaga ko kasi ikaw nagdidiscuss                                                                                                                                                                                                                                                                                                                                                                            You know, ma'am, we have a lot of fun philosophy topics. I'm just really sleepy in what you're discussing.    4.0               1.0        good      poor       3.0
#                                                                                                                                                                                                                                                                                                                I just want to be your everything.                                                                                                                                                                                                                                                                                                                                                                                                                                               Nais ko lang ay maging lahat para sa’yo    3.0               5.0        good excellent       2.0
#
# Mean absolute difference (|human - llm|): 1.263
#
# Saved detailed comparison to comparison_human_vs_llm.csv
